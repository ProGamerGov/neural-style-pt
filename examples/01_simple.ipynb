# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from model import *
from utils import *
from generate import *

# setup stylenet
params = StylenetArgs()
params.gpu = '0'
params.backend = 'cudnn'
params.model_file = '../models/vgg19-d01eb7cb.pth'

dtype, multidevice, backward_device = setup_gpu(params)
stylenet = StyleNet(params, dtype, multidevice, backward_device, verbose=False)
# Out:
# Model setup successfully with parameters:
# gpu: 0, optimizer: lbfgs, learning_rate: 1.00, lbfgs_num_correction: 100, pooling: max, model_file: ../models/vgg19-d01eb7cb.pth, False, backend: cudnn, False, content_layers: relu4_2, style_layers: relu1_1,relu2_1,relu3_1,relu4_1,relu5_1, hist_layers: relu2_1,relu3_1,relu4_1,relu5_1, multidevice_strategy: 4,7,29

# %%
# %load_ext autoreload
# %autoreload 2

#from neuralarttools import *
from neuralarttools.image import *
import neuralarttools.external.basnet as basnet
print(basnet)
# Out:
# <module 'neuralarttools.external.basnet' from '/home/bzion/projects/neural-art-tools/neuralarttools/external/basnet.py'>

# %% [markdown]
# ## Simple example
#
# Note: reconsider how `input_image` works.

# %%
config = {
    'content_image': '../images/inputs/monalisa.jpg',
    'style_image': '../images/inputs/hokusai.jpg'
}

img = style_transfer(stylenet, config)
display(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d022acd53829> in <module>
#       4 }
#       5
# ----> 6 img = style_transfer(stylenet, config)
#       7 display(img)
#
# ~/projects/neural-style-pt/generate.py in style_transfer(stylenet, config, input_image, verbose)
#      93         content_image_orig = deprocess(random_tensor(cfg.size[0], cfg.size[1]))
#      94     elif cfg.content_image is not None and isinstance(cfg.content_image, str):
# ---> 95         content_image_orig = load_image(cfg.content_image, cfg.size)
#      96         cfg.size = get_size(content_image_orig)  ### is this right??????
#      97     else:
#
# NameError: name 'load_image' is not defined

# %% [markdown]
# ## More customized
#
# Additional parameters to customize:
# * `size`: size of canvas (default 512). Either as tuple `(h, w)` or maximum dimension.
# * `style_scale`: At what scale resolution to extract style features fr om style images (deault 1.0)
# * `input_image`: Start canvas from another image, rather than from random.
# * `num_iterations`: How many steps for the optimization (default 1000)
# * `original_colors`: Once done, transfer color distribution to that of the content image.
#
# Note that all images, `content_image`, `style_images`, and `input_image` can all be either actual images or paths to saved images on disk.

# %%
config = {
    'size': 512, #(1024, 768), 
    'content_image': '../images/inputs/monalisa.jpg',
    'style_images': '../images/inputs/starry_night.jpg',
    'style_scale': 1.0,
    'num_iterations': 1000,
    'original_colors': True
}

img = style_transfer(stylenet, config)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=343x512 at 0x7FC0216A4390>

# %% [markdown]
# ## Multi-resolution
#
# Additional parameters to customize:
# * `num_octaves`: size of canvas (default 512). Either as tuple `(w, h)` or maximum dimension.
# * `octave_scale`: At what scale resolution to extract style features fr om style images (deault 1.0)
# * `num_iterations` and `style_scale` can be set as 1 element, i.e. same for each resolution, or as lists

# %%
config = {
    'size': (683, 1024),
    'content_image': '../images/inputs/monalisa.jpg',
    'style_images': '../images/inputs/the_scream.jpg',
    'num_iterations': [1000, 750, 500],
    'num_octaves': 3,
    'octave_ratio': 2.0
}

img = style_transfer(stylenet, config)
display(img)
# Out:
# <PIL.Image.Image image mode=RGB size=683x1024 at 0x7FC02163C4E0>

# %% [markdown]
# The output of an image can be saved.

# %%
save(img, 'media/my_example.png')

# %%
config = {
    'size': (768, 1024), 
    'content_image': '../images/inputs/monalisa.jpg',
    'style_images': ['../images/inputs/hokusai.jpg',
                     '../images/inputs/starry_night.jpg'],
    'content_masks': ['../images/masks/monalisa1b.png',
                      '../images/masks/monalisa1a.png'],
    'style_scale': 1.0,
    'num_iterations': [800, 500, 250],
    'num_octaves': 3,
    'octave_ratio': 1.8,
    'original_colors': False
}


img = style_transfer(stylenet, config)
display(img)

save(img, 'media/myimg.png')
# Out:
# <PIL.Image.Image image mode=RGB size=768x1024 at 0x7FC02163CE48>

# %%
config = {
    'size': (683, 1024),
    'content_image': '../images/inputs/monalisa.jpg',
    'style_images': 'https://cdn0.rubylane.com/_pod/item/440186/AJ2963/1967-x7827Collected-Drawings-Aubrey-Beardsleyx7827-First-full-1A-700%3A10.10-00000000-9.png',
    'num_iterations': [1000, 750, 500],
    'num_octaves': 3,
    'octave_ratio': 2.0
}

img = style_transfer(stylenet, config)
display(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c7ef3ffaff37> in <module>
#      13 }
#      14
# ---> 15 img = style_transfer(stylenet, config)
#      16 display(img)
#
# ~/projects/neural-style-pt/generate.py in style_transfer(stylenet, config, input_image, verbose)
#      93         content_image_orig = deprocess(random_tensor(cfg.size[0], cfg.size[1]))
#      94     elif cfg.content_image is not None and isinstance(cfg.content_image, str):
# ---> 95         content_image_orig = load_image(cfg.content_image, cfg.size)
#      96         cfg.size = get_size(content_image_orig)  ### is this right??????
#      97     else:
#
# NameError: name 'load_image' is not defined
